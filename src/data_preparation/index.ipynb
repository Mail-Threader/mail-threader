# %%
import pandas as pd

# %%
df = pd.read_pickle("../../output/processed_data/processed_data_20250615_103337.pkl")

# %%
df
# Out:
#                                               message_id  \
# 0          <22558080.1075841861972.JavaMail.evans@thyme>
# 1          <13922544.1075844273941.JavaMail.evans@thyme>
# 2           <3930064.1075862338635.JavaMail.evans@thyme>
# 3      <3930064.1075862338635.JavaMail.evans@thyme>_o...
# 4      <3930064.1075862338635.JavaMail.evans@thyme>_o...
# ...                                                  ...
# 10540      <16501206.1075860372925.JavaMail.evans@thyme>
# 10541       <1145212.1075861322431.JavaMail.evans@thyme>
# 10542       <6493360.1075862554728.JavaMail.evans@thyme>
# 10543       <8418713.1075842959013.JavaMail.evans@thyme>
# 10544       <5230632.1075848343178.JavaMail.evans@thyme>
#
#                                             main_id filename      type  \
# 0                                              None    1. 10      main
# 1                                              None    1. 11      main
# ...
